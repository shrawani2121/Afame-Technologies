# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/ECOMM DATA.xlsx - Orders.csv')
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   31/7/2012   31/7/2012        Same Day
# 1       26341    IN-2013-77878    5/2/2013    7/2/2013    Second Class
# 2       25330    IN-2013-71249  17/10/2013  18/10/2013     First Class
# 3       13524  ES-2013-1579342   28/1/2013   30/1/2013     First Class
# 4       47221     SG-2013-4320   5/11/2013   6/11/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366   19/6/2014   19/6/2014        Same Day
# 51286   35398   US-2014-102288   20/6/2014   24/6/2014  Standard Class
# 51287   40470   US-2013-155768   2/12/2013   2/12/2013        Same Day
# 51288    9596   MX-2012-140767   18/2/2012   22/2/2012  Standard Class
# 51289    6147   MX-2012-134460   22/5/2012   26/5/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
# Out:
# <ipython-input-26-9d9e7d6e3ad3>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
# <ipython-input-26-9d9e7d6e3ad3>:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
plt.hist(df['Sales'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(x='Quantity',data=df)
plt.show()

# %%
sns.countplot(x='State',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# State with highest sales
sales_by_state = df.groupby('State')['Sales'].sum()
highest_sales_state = sales_by_state.idxmax()
plt.figure(figsize=(10, 6))
plt.bar(sales_by_state.index, sales_by_state.values, color='orange')
plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Total Sales by State')
plt.bar(highest_sales_state, sales_by_state[highest_sales_state], color='red', label=f'Highest Sales ({highest_sales_state})')
plt.show()

# %%
# which Category has highest sales
sales_by_state = df.groupby('Category')['Sales'].sum()
highest_sales_state = sales_by_state.idxmax()
plt.figure(figsize=(10, 6))
plt.bar(sales_by_state.index, sales_by_state.values, color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Total Sales by Category')
plt.bar(highest_sales_state, sales_by_state[highest_sales_state], color='green', label=f'Highest Sales ({highest_sales_state})')
plt.show()

# %%
# which sub category has highest sales
sales_by_state = df.groupby('Sub-Category')['Sales'].sum()
highest_sales_state = sales_by_state.idxmax()
plt.figure(figsize=(10, 6))
plt.bar(sales_by_state.index, sales_by_state.values, color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Total Sales by Sub-Category')
plt.bar(highest_sales_state, sales_by_state[highest_sales_state], color='red', label=f'Highest Sales ({highest_sales_state})')
plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
#which city in each state has highest sales
highest_sales_per_state =df.groupby('State').apply(lambda x: x.loc[x['Sales'].idxmax()])
print(highest_sales_per_state[[ 'City']])
# Out:
#                                  City
# State
# Alabama                        Mobile
# Arizona                       Phoenix
# Arkansas                 Fayetteville
# California              San Francisco
# Colorado                   Louisville
# Connecticut                   Meriden
# Delaware                       Newark
# District of Columbia       Washington
# Florida                  Jacksonville
# Georgia                       Atlanta
# Idaho                      Twin Falls
# Illinois                      Chicago
# Indiana                     Lafayette
# Iowa                          Dubuque
# Kansas                  Overland Park
# Kentucky                     Florence
# Louisiana                   Lafayette
# Maine                          Bangor
# Maryland                     Columbia
# Massachusetts                 Beverly
# Michigan                      Detroit
# Minnesota                 Minneapolis
# Mississippi                   Jackson
# ...

# %%
# Top 5 States with highest sales
sales_by_state = df.groupby('State')['Sales'].sum()
sorted_states = sales_by_state.sort_values(ascending=False)
top_5_states = sorted_states.head(5)
plt.figure(figsize=(3,3))
plt.pie(top_5_states, labels=top_5_states.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 States with Highest Sales')
plt.axis('equal')
plt.show()

# %%
#Top 10 higeshst selling products
sales_by_product = df.groupby('Product Name')['Sales'].sum()
sorted_products = sales_by_product.sort_values(ascending=False)
top_10_products = sorted_products.head(10)
plt.figure(figsize=(10, 6))
top_10_products.plot(kind='bar', color='skyblue')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.title('Top 10 Products with Highest Sales')
plt.xticks(rotation=90)
plt.show()

# %%
# which segment has highest sales
sales_by_segment =df.groupby('Segment')['Sales'].sum()
highest_sales_segment = sales_by_segment.idxmax()
plt.figure(figsize=(10, 6))
sales_by_segment.plot(kind='bar', color='skyblue')
plt.xlabel('Segment')
plt.ylabel('Total Sales')
plt.title('Total Sales by Segment')
plt.bar(highest_sales_segment, sales_by_segment[highest_sales_segment], color='red', label=f'Highest Sales ({highest_sales_segment})')
plt.show()

# %%
# Which region has highest sales
sales_by_region =df.groupby('Region')['Sales'].sum()
highest_sales_region = sales_by_region.idxmax()
plt.figure(figsize=(10, 6))
sales_by_region.plot(kind='bar', color='brown')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region')
plt.bar(highest_sales_region, sales_by_region[highest_sales_region], color='grey', label=f'Highest Sales ({highest_sales_region})')
plt.show()

# %%
# What Quantity has highest discount
discount_by_quantity =df.groupby('Quantity')['Discount'].sum()
highest_discount_quantity = discount_by_quantity.idxmax()
plt.figure(figsize=(10, 6))
discount_by_quantity.plot(kind='line', color='skyblue')
plt.xlabel('Quantity')
plt.ylabel('Total Discount')
plt.title('Total Discount by Quantity')
plt.plot(highest_discount_quantity, discount_by_quantity[highest_discount_quantity], marker='o', markersize=8, color='red', label=f'Highest Discount ({highest_discount_quantity})')
plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# Which category has highest profit
profit_by_category =df.groupby('Category')['Profit'].sum()
highest_profit_category = profit_by_category.idxmax()
plt.figure(figsize=(3,3))
plt.pie(profit_by_category, labels=profit_by_category.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Profit by Category')
plt.axis('equal')
plt.show()

# %%
# Top 5 products with highest discount
sales_by_product =df.groupby('Product Name')['Sales'].sum()
sorted_products = sales_by_product.sort_values(ascending=False)
top_5_products = sorted_products.head(5)
print(top_5_products)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# Name: Sales, dtype: float64

# %%
# Top 10 product with most shipping cost
shipping_cost_by_product =df.groupby('Product Name')['Shipping Cost'].sum()
sorted_products = shipping_cost_by_product.sort_values(ascending=False)
top_10_products = sorted_products.head(10)
plt.figure(figsize=(12, 6))
top_10_products.plot(kind='bar', color='orange')

plt.xlabel('Product')
plt.ylabel('Total Shipping Cost')
plt.title('Top 10 Products with Highest Shipping Cost')
plt.xticks(rotation=90)
plt.show()

# %%
df.to_csv('/content/ECOMM DATA.xlsx - Orders.csv', index=False)
